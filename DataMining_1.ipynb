# %% [markdown]
# ## О Jupyter notebook

# %% [markdown]
# Jupyter Notebook — это среда разработки, где сразу можно видеть результат выполнения кода и его отдельных фрагментов. Отличие от традиционной среды разработки в том, что код можно разбить на куски и выполнять их в произвольном порядке.
# Для запуска кода в ячейке можно воспользоваться меню сверху или нажать клавиши "Enter+Shift".
#
# Основная область применения ноутбуков — машинное обучение, нейросети, визуализация данных и статистика.
#
# Ещё такую среду часто используют для поэтапной разработки, когда нужно по шагам проверять работу разных фрагментов кода. Дело в том, что код в ноутбуках хранится в независимых ячейках и его можно запускать в любом порядке или поодиночке. Это позволяет быстро экспериментировать с алгоритмами и находить оптимальное решение.
#
# Также jupyter-ноутбуки используются при обучении программированию на Python, чтобы писать код и сразу видеть результат его работы.
#
# Есть два основных типа ячеек, которые мы рассмотрим:
#
# - Ячейка кода содержит код, который должен быть выполнен в ядре, и отображает его вывод ниже.
# - Ячейка Markdown содержит текст, отформатированный с использованием Markdown, и отображает его вывод на месте при запуске.

# %%
# ячейка с кодом, при выполнении которой появится output
2 + 2

# %% [markdown]
# А это ___ячейка с текстом___.

# %% [raw]
# Ячейка с неразмеченыным текстом.

# %% [markdown]
# Попробуйте создать свои ячейки, написать какой-нибудь код и текст какой-нибудь формулой.

# %%
print("Boom!")
# Out:
# Boom!

# %% [markdown]
# [Здесь](https://athena.brynmawr.edu/jupyter/hub/dblank/public/Jupyter%20Notebook%20Users%20Manual.ipynb) находится <s>не</s>большая заметка о используемом языке разметки Markdown. Он позволяет:
#
# 0. Составлять упорядоченные списки
# 1. #Делать
# ##заголовки
# ###разного уровня
# 3. Выделять *текст* <s>при</s> **необходимости**
# 4. Добавлять [ссылки](http://imgs.xkcd.com/comics/the_universal_label.png)
#
#
# * Составлять неупорядоченные списки
#
# Делать вставки с помощью LaTex:
#
# $
# \left\{
# \begin{array}{ll}
# x = 16 \sin^3 (t) \\
# y = 13 \cos (t) - 5 \cos (2t) - 2 \cos (3t) - \cos (4t) \\
# t \in [0, 2 \pi]
# \end{array}
# \right.$

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %% [markdown]
# Pandas — это библиотека для работы с данными на Python. Она упрощает жизнь аналитикам: где раньше использовалось 10 строк кода теперь хватит одной.
#
# Например, чтобы прочитать данные из csv, в стандартном Python надо сначала решить, как хранить данные, затем открыть файл, прочитать его построчно, отделить значения друг от друга и очистить данные от специальных символов.
#
# В Pandas всё проще. Во-первых, не нужно думать, как будут храниться данные — они лежат в датафрейме. Во-вторых, достаточно написать одну команду:
#
#  data = pd.read_csv('file.csv')
#
# Pandas добавляет в Python новые структуры данных — серии и датафреймы.
#
# Серии — одномерные массивы данных. Они очень похожи на списки, но отличаются по поведению — например, операции применяются к списку целиком, а в сериях — поэлементно.
# Еще одно отличие серий от списков — в качестве индексов можно использовать произвольные значения, это делает данные нагляднее.
# Датафрейм — это проиндексированный многомерный массив значений, соответственно каждый столбец датафрейма, является серией.

# %%
# %pylab inline  
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# #### 1. Прочитайте файл с таблицей, выведите последние 10 строк.

# %%
data = pd.read_csv('../data_for_lab_1.csv')
data.tail(10)
# Out:
#                       event_time             order_id           product_id  \
# 2633511  2020-11-21 10:05:04 UTC  2388440981134693938  1515966223509088509
# 2633512  2020-11-21 10:06:01 UTC  2388440981134693939  1515966223509090132
# 2633513  2020-11-21 10:08:14 UTC  2388440981134693940  2273948246856434093
# 2633514  2020-11-21 10:08:54 UTC  2388440981134693941  1515966223519279912
# 2633515  2020-11-21 10:08:54 UTC  2388440981134693941  1515966223509088622
# 2633516  2020-11-21 10:10:01 UTC  2388440981134693942  1515966223526602848
# 2633517  2020-11-21 10:10:13 UTC  2388440981134693943  1515966223509089282
# 2633518  2020-11-21 10:10:30 UTC  2388440981134693944  1515966223509089917
# 2633519  2020-11-21 10:10:30 UTC  2388440981134693944  2273948184839454837
# 2633520  2020-11-21 10:10:30 UTC  2388440981134693944  1515966223509127566
#
#           category_id                  category_code     brand    price  \
# 2633511  2.268105e+18         electronics.smartphone     apple   925.67
# 2633512  2.268105e+18  computers.peripherals.printer     canon   299.98
# 2633513  2.268105e+18                            NaN    xiaomi    16.18
# 2633514  2.374499e+18           electronics.video.tv   samsung  1736.09
# 2633515  2.374499e+18           electronics.video.tv        lg   370.35
# 2633516  2.268105e+18         electronics.smartphone      oppo   138.87
# 2633517  2.268105e+18         electronics.smartphone     apple   418.96
# 2633518  2.268105e+18     appliances.personal.scales     vitek    12.48
# 2633519  2.268105e+18                            NaN  moulinex    41.64
# 2633520  2.268105e+18     appliances.kitchen.blender   redmond    53.22
#
#               user_id
# 2633511  1.515916e+18
# 2633512  1.515916e+18
# 2633513  1.515916e+18
# 2633514  1.515916e+18
# 2633515  1.515916e+18
# 2633516  1.515916e+18
# 2633517  1.515916e+18
# 2633518  1.515916e+18
# 2633519  1.515916e+18
# 2633520  1.515916e+18

# %% [markdown]
# #### 2.  Выведите следующую информацию:
# 1. Сколько всего заказов в исходной выборке данных?
# 2. Количество уникальных категорий товара (category_code)

# %%
print(f"Всего заказов в исходной выборке данных: {len(data)}")
print(f"Количество уникальных категорий товара: {len(data['category_code'].unique())}")
# Out:
# Всего заказов в исходной выборке данных: 2633521
# Количество уникальных категорий товара: 511

# %% [markdown]
# #### 3. Найдите столбцы с пустыми значениями, заполните строковые значения пустой строкой, числовые - 0.

# %%
print(f"Сумма столбцов с NaN-значениями:\n{data.isnull().sum()}")
# Out:
# Сумма столбцов с NaN-значениями:
# event_time             0
# order_id               0
# product_id             0
# category_id       431954
# category_code     612202
# brand             506005
# price             431954
# user_id          2069352
# dtype: int64

# %%
data = data.fillna(value={"category_id":0, "category_code":"","brand":"","price":0,"user_id":0})
print(f"Сумма столбцов с NaN-значениями:\n{data.isnull().sum()}") #проверяем, что замена произвелась
# Out:
# Сумма столбцов с NaN-значениями:
# event_time       0
# order_id         0
# product_id       0
# category_id      0
# category_code    0
# brand            0
# price            0
# user_id          0
# dtype: int64

# %% [markdown]
# #### 4.  Обратите внимание на колонку, содержащую цену товара. Создайте новую колонку, таким образом, чтобы цена стала числом.
#
# Для этого необходимо применить функцию-преобразование к каждой строке таблицы (для этого есть соответствующая функция).

# %%
data["product_price"] = np.nan #замена на NaN
data
# Out:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 1        2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 2        2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 3        2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 4        2020-04-24 19:16:21 UTC  2294584263154074236  2273948316817424439
# ...                          ...                  ...                  ...
# 2633516  2020-11-21 10:10:01 UTC  2388440981134693942  1515966223526602848
# 2633517  2020-11-21 10:10:13 UTC  2388440981134693943  1515966223509089282
# 2633518  2020-11-21 10:10:30 UTC  2388440981134693944  1515966223509089917
# 2633519  2020-11-21 10:10:30 UTC  2388440981134693944  2273948184839454837
# 2633520  2020-11-21 10:10:30 UTC  2388440981134693944  1515966223509127566
#
#           category_id                category_code     brand   price  \
# 0        2.268105e+18           electronics.tablet   samsung  162.01
# 1        2.268105e+18           electronics.tablet   samsung  162.01
# 2        2.268105e+18  electronics.audio.headphone    huawei   77.52
# 3        2.268105e+18  electronics.audio.headphone    huawei   77.52
# 4        2.268105e+18                                karcher  217.57
# ...               ...                          ...       ...     ...
# 2633516  2.268105e+18       electronics.smartphone      oppo  138.87
# 2633517  2.268105e+18       electronics.smartphone     apple  418.96
# 2633518  2.268105e+18   appliances.personal.scales     vitek   12.48
# 2633519  2.268105e+18                               moulinex   41.64
# 2633520  2.268105e+18   appliances.kitchen.blender   redmond   53.22
#
#               user_id  product_price
# 0        1.515916e+18            NaN
# 1        1.515916e+18            NaN
# 2        1.515916e+18            NaN
# 3        1.515916e+18            NaN
# 4        1.515916e+18            NaN
# ...               ...            ...
# 2633516  1.515916e+18            NaN
# 2633517  1.515916e+18            NaN
# 2633518  1.515916e+18            NaN
# 2633519  1.515916e+18            NaN
# 2633520  1.515916e+18            NaN
#
# [2633521 rows x 9 columns]

# %%
data["product_price"] = data["price"]

# %%
data=data.astype({"product_price": np.float64}) #переводим в другой формат и проверяем 
print(f"Типы столбцов:\n{data.dtypes}") #можно сделать другими способами (to_numaric?)
# Out:
# Типы столбцов:
# event_time        object
# order_id           int64
# product_id         int64
# category_id      float64
# category_code     object
# brand             object
# price            float64
# user_id          float64
# product_price    float64
# dtype: object

# %% [markdown]
# Выведите среднюю/минимальную/максимальную цену у товара.

# %%
data["product_price"].replace(0, np.NaN).max() #не учитываем нулевые значения, чтобы соблюсти точность
# Out:
# 50925.9

# %%
data["product_price"].replace(0, np.NaN).min()
# Out:
# 0.02

# %%
data["product_price"].replace(0, np.NaN).mean()
# Out:
# 154.1016348843336

# %%
data=data.drop(columns=["product_price"])

# %% [markdown]
# Удалите старую колонку с ценой.

# %%
data
# Out:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 1        2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 2        2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 3        2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 4        2020-04-24 19:16:21 UTC  2294584263154074236  2273948316817424439
# ...                          ...                  ...                  ...
# 2633516  2020-11-21 10:10:01 UTC  2388440981134693942  1515966223526602848
# 2633517  2020-11-21 10:10:13 UTC  2388440981134693943  1515966223509089282
# 2633518  2020-11-21 10:10:30 UTC  2388440981134693944  1515966223509089917
# 2633519  2020-11-21 10:10:30 UTC  2388440981134693944  2273948184839454837
# 2633520  2020-11-21 10:10:30 UTC  2388440981134693944  1515966223509127566
#
#           category_id                category_code     brand   price  \
# 0        2.268105e+18           electronics.tablet   samsung  162.01
# 1        2.268105e+18           electronics.tablet   samsung  162.01
# 2        2.268105e+18  electronics.audio.headphone    huawei   77.52
# 3        2.268105e+18  electronics.audio.headphone    huawei   77.52
# 4        2.268105e+18                                karcher  217.57
# ...               ...                          ...       ...     ...
# 2633516  2.268105e+18       electronics.smartphone      oppo  138.87
# 2633517  2.268105e+18       electronics.smartphone     apple  418.96
# 2633518  2.268105e+18   appliances.personal.scales     vitek   12.48
# 2633519  2.268105e+18                               moulinex   41.64
# 2633520  2.268105e+18   appliances.kitchen.blender   redmond   53.22
#
#               user_id
# 0        1.515916e+18
# 1        1.515916e+18
# 2        1.515916e+18
# 3        1.515916e+18
# 4        1.515916e+18
# ...               ...
# 2633516  1.515916e+18
# 2633517  1.515916e+18
# 2633518  1.515916e+18
# 2633519  1.515916e+18
# 2633520  1.515916e+18
#
# [2633521 rows x 8 columns]

# %% [markdown]
# #### 5. Отсортируйте стоимость товаров по убыванию, выведите 7 дорогих товаров. Отсортируйте товары по возрастанию стоимости, выведите 7 дешевых товаров  (по choice_description)
#
# Для этого избавьтесь от дубликатов и отсортируйте товары. Не забудьте про количество товара.

# %%
data_new=data.sort_values(by="price",ascending = False)
data_new #по убыванию
# Out:
#                       event_time             order_id           product_id  \
# 1144303  2020-05-26 08:12:38 UTC  2353234364520727464  1515966223509105016
# 28182    2020-06-25 10:08:37 UTC  2339244674033647628  1515966223509131884
# 28623    2020-06-26 09:10:44 UTC  2339940319191106553  1515966223509566954
# 1627981  2020-07-03 11:59:01 UTC  2353288509000777918  2273948305316643078
# 1153319  2020-05-27 06:37:30 UTC  2353235498996073224  2273948305316643078
# ...                          ...                  ...                  ...
# 920347   2020-03-28 07:17:06 UTC  2348826594421768924  1515966223523303301
# 371198   2020-02-06 13:16:06 UTC  2348786675955532663  1515966223523303310
# 920345   2020-03-28 07:17:06 UTC  2348826594421768924  1515966223523303306
# 920344   2020-03-28 07:17:06 UTC  2348826594421768924  1515966223527473726
# 1982655  2020-08-24 06:46:37 UTC  2383131895429857556  1515966223523303302
#
#           category_id         category_code    brand     price       user_id
# 1144303  2.374499e+18  electronics.video.tv  samsung  50925.90  0.000000e+00
# 28182    2.374499e+18  electronics.video.tv           18328.68  1.515916e+18
# 28623    2.374499e+18  electronics.video.tv           13310.16  1.515916e+18
# 1627981  2.268105e+18  electronics.video.tv       lg  11574.05  1.515916e+18
# 1153319  2.268105e+18  electronics.video.tv       lg  11574.05  0.000000e+00
# ...               ...                   ...      ...       ...           ...
# 920347   0.000000e+00                 16.18               0.00  0.000000e+00
# 371198   0.000000e+00                  8.10               0.00  0.000000e+00
# 920345   0.000000e+00                  4.63               0.00  0.000000e+00
# 920344   0.000000e+00                 25.46               0.00  0.000000e+00
# 1982655  0.000000e+00                 57.87               0.00  0.000000e+00
#
# [2633521 rows x 8 columns]

# %%
data_new=data.sort_values(by='price',ascending=False).head(7)
data_new #семь самых дорогих
# Out:
#                       event_time             order_id           product_id  \
# 1144303  2020-05-26 08:12:38 UTC  2353234364520727464  1515966223509105016
# 28182    2020-06-25 10:08:37 UTC  2339244674033647628  1515966223509131884
# 28623    2020-06-26 09:10:44 UTC  2339940319191106553  1515966223509566954
# 1627981  2020-07-03 11:59:01 UTC  2353288509000777918  2273948305316643078
# 1153319  2020-05-27 06:37:30 UTC  2353235498996073224  2273948305316643078
# 2270999  2020-09-16 06:46:10 UTC  2388440981134484484  1515966223520801280
# 8742     2020-05-14 09:09:41 UTC  2308774433587724743  1515966223509105377
#
#           category_id           category_code    brand     price       user_id
# 1144303  2.374499e+18    electronics.video.tv  samsung  50925.90  0.000000e+00
# 28182    2.374499e+18    electronics.video.tv           18328.68  1.515916e+18
# 28623    2.374499e+18    electronics.video.tv           13310.16  1.515916e+18
# 1627981  2.268105e+18    electronics.video.tv       lg  11574.05  1.515916e+18
# 1153319  2.268105e+18    electronics.video.tv       lg  11574.05  0.000000e+00
# 2270999  2.374499e+18    electronics.video.tv  samsung  10416.64  1.515916e+18
# 8742     2.268105e+18  electronics.smartphone       lg   9606.48  1.515916e+18

# %%
data_new=data.sort_values(by="price") #по возрастанию и 7 самых дешевых
data_new=data_new[data_new['price']>0]
data_new.head(7)
# Out:
#                       event_time             order_id           product_id  \
# 7468     2020-05-12 10:53:34 UTC  2307377169208181572  1515966223510032494
# 2470733  2020-10-09 11:23:33 UTC  2388440981134595839  1515966223509261546
# 1805277  2020-08-05 10:38:31 UTC  2369353908226097685  1515966223509261546
# 1017468  2020-07-14 04:50:31 UTC  2352855308012880346  2309018260231684957
# 2470715  2020-10-09 11:17:39 UTC  2388440981134595824  1515966223509261546
# 2470713  2020-10-09 11:15:12 UTC  2388440981134595822  1515966223509261546
# 2607696  2020-11-14 07:15:40 UTC  2388440981134679013  1515966223509261546
#
#           category_id       category_code     brand  price       user_id  \
# 7468     2.268105e+18  computers.notebook      none   0.02  1.515916e+18
# 2470733  2.268105e+18          kids.dolls  x-cooler   0.21  1.515916e+18
# 1805277  2.268105e+18          kids.dolls  x-cooler   0.21  0.000000e+00
# 1017468  2.268106e+18       apparel.glove   rossija   0.21  1.515916e+18
# 2470715  2.268105e+18          kids.dolls  x-cooler   0.21  1.515916e+18
# 2470713  2.268105e+18          kids.dolls  x-cooler   0.21  1.515916e+18
# 2607696  2.268105e+18          kids.dolls  x-cooler   0.21  1.515916e+18
#
#          check        date       Date  Day
# 7468      0.02  2018-01-22 2018-01-22    0
# 2470733   0.21  2018-01-19 2018-01-19    4
# 1805277   4.82  2018-01-11 2018-01-11    3
# 1017468   0.88  2018-01-18 2018-01-18    3
# 2470715   0.21  2018-01-14 2018-01-14    6
# 2470713   0.21  2018-01-23 2018-01-23    1
# 2607696   0.21  2018-01-16 2018-01-16    1

# %% [markdown]
# #### 6. Выведите информацию о том, сколько раз клиенты покупали больше 1 товара apple (brand)?

# %%
data_new_1=data[(data['brand']=='apple')]
data_new_1[data_new_1['product_id'].gt(1)] #единый адишник
# Out:
#                       event_time             order_id           product_id  \
# 6        2020-04-26 09:33:47 UTC  2295740594749702229  1515966223509104892
# 7        2020-04-26 09:33:47 UTC  2295740594749702229  1515966223509104892
# 8        2020-04-26 09:33:47 UTC  2295740594749702229  1515966223509104892
# 9        2020-04-26 09:33:47 UTC  2295740594749702229  1515966223509104892
# 34       2020-04-29 10:46:21 UTC  2297951447913857849  1515966223509088613
# ...                          ...                  ...                  ...
# 2633478  2020-11-21 09:27:12 UTC  2388440981134693910  2388434452476864403
# 2633482  2020-11-21 09:30:48 UTC  2388440981134693913  1515966223509088509
# 2633510  2020-11-21 10:04:42 UTC  2388440981134693937  1515966223509088671
# 2633511  2020-11-21 10:05:04 UTC  2388440981134693938  1515966223509088509
# 2633517  2020-11-21 10:10:13 UTC  2388440981134693943  1515966223509089282
#
#           category_id                category_code  brand    price  \
# 6        2.268105e+18       electronics.smartphone  apple  1387.01
# 7        2.268105e+18       electronics.smartphone  apple  1387.01
# 8        2.268105e+18       electronics.smartphone  apple  1387.01
# 9        2.268105e+18       electronics.smartphone  apple  1387.01
# 34       2.268105e+18  electronics.audio.headphone  apple   203.68
# ...               ...                          ...    ...      ...
# 2633478  2.268105e+18       electronics.smartphone  apple  1006.92
# 2633482  2.268105e+18       electronics.smartphone  apple   925.67
# 2633510  2.268105e+18       electronics.smartphone  apple   925.67
# 2633511  2.268105e+18       electronics.smartphone  apple   925.67
# 2633517  2.268105e+18       electronics.smartphone  apple   418.96
#
#               user_id
# 6        1.515916e+18
# 7        1.515916e+18
# 8        1.515916e+18
# 9        1.515916e+18
# 34       1.515916e+18
# ...               ...
# 2633478  1.515916e+18
# 2633482  1.515916e+18
# 2633510  1.515916e+18
# 2633511  1.515916e+18
# 2633517  1.515916e+18
#
# [74709 rows x 8 columns]

# %% [markdown]
# #### 7. Выведите информацию о среднем чеке у заказа и сколько в среднем товаров покупают?
#
# Если необходимо провести вычисления в терминах заказов, то будет удобно сгруппировать строки по заказам и посчитать необходимые значения.

# %%
print(f"Средний чек у заказа:\n{data.groupby('order_id').agg({'price':'sum'}).mean()}")
# Out:
# Средний чек у заказа:
# price    236.364846
# dtype: float64

# %%
print(f"Покупают товаров в среднем:\n{data['order_id'].value_counts().mean()}")
# Out:
# Покупают товаров в среднем:
# 1.8348661502467138

# %% [markdown]
# #### 8. Выведите количество заказов с 1 товаром.

# %%
data_new_2 = data.groupby(['order_id']).agg({'product_id':'count'}) #обобщение данных
count_1 = data_new_2.loc[data_new_2['product_id'] == 1].size
print(f"Количество заказов с 1 товаром:\n{count_1}")
# Out:
# Количество заказов с 1 товаром:
# 871751

# %% [markdown]
# #### 9. Выведите самую популярную категорию товара.

# %%
data['category_code'].replace('', np.nan, inplace=True) 
#заменим все пустые строки в категории кода на np.nan объекты
data
# Out:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 1        2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 2        2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 3        2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 4        2020-04-24 19:16:21 UTC  2294584263154074236  2273948316817424439
# ...                          ...                  ...                  ...
# 2633516  2020-11-21 10:10:01 UTC  2388440981134693942  1515966223526602848
# 2633517  2020-11-21 10:10:13 UTC  2388440981134693943  1515966223509089282
# 2633518  2020-11-21 10:10:30 UTC  2388440981134693944  1515966223509089917
# 2633519  2020-11-21 10:10:30 UTC  2388440981134693944  2273948184839454837
# 2633520  2020-11-21 10:10:30 UTC  2388440981134693944  1515966223509127566
#
#           category_id                category_code     brand   price  \
# 0        2.268105e+18           electronics.tablet   samsung  162.01
# 1        2.268105e+18           electronics.tablet   samsung  162.01
# 2        2.268105e+18  electronics.audio.headphone    huawei   77.52
# 3        2.268105e+18  electronics.audio.headphone    huawei   77.52
# 4        2.268105e+18                          NaN   karcher  217.57
# ...               ...                          ...       ...     ...
# 2633516  2.268105e+18       electronics.smartphone      oppo  138.87
# 2633517  2.268105e+18       electronics.smartphone     apple  418.96
# 2633518  2.268105e+18   appliances.personal.scales     vitek   12.48
# 2633519  2.268105e+18                          NaN  moulinex   41.64
# 2633520  2.268105e+18   appliances.kitchen.blender   redmond   53.22
#
#               user_id
# 0        1.515916e+18
# 1        1.515916e+18
# 2        1.515916e+18
# 3        1.515916e+18
# 4        1.515916e+18
# ...               ...
# 2633516  1.515916e+18
# 2633517  1.515916e+18
# 2633518  1.515916e+18
# 2633519  1.515916e+18
# 2633520  1.515916e+18
#
# [2633521 rows x 8 columns]

# %%
data.dropna(subset=["category_code"], inplace=True) ##отбросим нулевые значения
data
# Out:
#                       event_time             order_id           product_id  \
# 0        2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 1        2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 2        2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 3        2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 5        2020-04-26 08:45:57 UTC  2295716521449619559  1515966223509261697
# ...                          ...                  ...                  ...
# 2633515  2020-11-21 10:08:54 UTC  2388440981134693941  1515966223509088622
# 2633516  2020-11-21 10:10:01 UTC  2388440981134693942  1515966223526602848
# 2633517  2020-11-21 10:10:13 UTC  2388440981134693943  1515966223509089282
# 2633518  2020-11-21 10:10:30 UTC  2388440981134693944  1515966223509089917
# 2633520  2020-11-21 10:10:30 UTC  2388440981134693944  1515966223509127566
#
#           category_id                category_code    brand   price  \
# 0        2.268105e+18           electronics.tablet  samsung  162.01
# 1        2.268105e+18           electronics.tablet  samsung  162.01
# 2        2.268105e+18  electronics.audio.headphone   huawei   77.52
# 3        2.268105e+18  electronics.audio.headphone   huawei   77.52
# 5        2.268105e+18      furniture.kitchen.table  maestro   39.33
# ...               ...                          ...      ...     ...
# 2633515  2.374499e+18         electronics.video.tv       lg  370.35
# 2633516  2.268105e+18       electronics.smartphone     oppo  138.87
# 2633517  2.268105e+18       electronics.smartphone    apple  418.96
# 2633518  2.268105e+18   appliances.personal.scales    vitek   12.48
# 2633520  2.268105e+18   appliances.kitchen.blender  redmond   53.22
#
#               user_id
# 0        1.515916e+18
# 1        1.515916e+18
# 2        1.515916e+18
# 3        1.515916e+18
# 5        1.515916e+18
# ...               ...
# 2633515  1.515916e+18
# 2633516  1.515916e+18
# 2633517  1.515916e+18
# 2633518  1.515916e+18
# 2633520  1.515916e+18
#
# [2021319 rows x 8 columns]

# %%
print(f"Самая популярная категория товара:\n{data['category_code'].value_counts()}")
#до этого выводило 60000+ пустых категорий
# Out:
# Самая популярная категория товара:
# electronics.smartphone              357682
# appliances.kitchen.refrigerators     77386
# 16.18                                72969
# electronics.video.tv                 71711
# computers.notebook                   71436
#                                      ...
# 31.25                                    1
# 106.43                                   1
# 92.34                                    1
# 31.94                                    1
# 347.20                                   1
# Name: category_code, Length: 510, dtype: int64

# %% [markdown]
# #### 10. Выведите виды товаров Apple. Какой из них чаще всего покупают? Какой из них самый дорогой?

# %%
data_3=data[(data['brand']=='apple')]
data_3['category_code'].value_counts() #общее количество по покупам категории
data_3.groupby('category_code').agg({'price':['max','count']}) #обобщаем
# Out:
#                                   price
#                                     max  count
# category_code
# computers.components.cooler      115.72    217
# computers.components.hdd         339.10    725
# computers.desktop               6018.50    174
# computers.notebook              5370.35   3922
# computers.peripherals.keyboard   648.13    127
# computers.peripherals.mouse      212.94    256
# construction.tools.screw          73.36   1254
# electronics.audio.headphone      324.05   9568
# electronics.clocks               601.83   5799
# electronics.smartphone          2002.29  46030
# electronics.tablet              2189.79   2578

# %% [markdown]
# #### 11. В каком количестве заказов есть товар, который стоит более 40% от суммы всего чека?
#
# Возможно, будет удобно посчитать отдельно средний чек, добавить его в исходные данные и сделать необходимые проверки.

# %%
data_ch = data.groupby('order_id')['price'].sum() #средний чек
data['check'] = data['order_id'].map(data_ch) #каждое значение от одного к другому
tov = data.loc[data['price'] > 0.4 * data['check']].size
tov - count_1
##количество заказов с товаром менее > количество товаров с 40%, вычитаем и получаем
# Out:
# 13637197

# %% [markdown]
# #### 12. Предположим, что в данных была ошибка и товар с product_id 1515966223509089906, который стоил 162.01, должен был стоить 170,02. Скорректируйте данные в таблицы и посчитайте, на какой процент больше денег было заработано с этого товара. Не забывайте, что количество товара не всегда равно 1.

# %%
data.loc[((data['product_id'] == 1515966223509089906) & (data['price'] == 162.01)), 'price'] = 170.02
data_error = data[data['product_id'] == 1515966223509089906]
preview = data_error.size * 162.01 #задаем, чтобы посчитать проценты
now = data_error.size * 170.02
print(round((now - preview)/preview * 100, 2), "%")
# Out:
# 4.94 %

# %% [markdown]
# #### 13. Создайте новый DateFrame из матрицы, созданной ниже. Назовите колонки index, column1, column2 и сделайте первую колонку индексом.

# %%
data = np.random.rand(10, 3)
df = pd.DataFrame(data, columns=['index', 'column1', 'column2'], index=data[:,0])
df
# Out:
#              index   column1   column2
# 0.150891  0.150891  0.233744  0.906126
# 0.565443  0.565443  0.551372  0.439513
# 0.444615  0.444615  0.929078  0.113924
# 0.517192  0.517192  0.498403  0.892873
# 0.699959  0.699959  0.513643  0.960186
# 0.070278  0.070278  0.785483  0.953983
# 0.839726  0.839726  0.190059  0.586972
# 0.098161  0.098161  0.338999  0.123865
# 0.809148  0.809148  0.976018  0.147040
# 0.550219  0.550219  0.350678  0.053216

# %% [markdown]
# Сохраните DataFrame локально в формате csv без индексов и названий столбцов.

# %%
df.to_csv('data_new_7.csv', index=False, header=False)

# %% [markdown]
# ## 2. Визуализации и matplotlib

# %% [markdown]
# Библиотека matplotlib - это бибилиотека двумерной графики для языка программирования python с помощью которой можно создавать высококачественные рисунки различных форматов. Matplotlib представляет собой модуль-пакет для python.
# Matplotlib cостоит из множества модулей. Модули наполнены различными классами и функциями, которые иерархически связаны между собой.

# %%
# %matplotlib inline  
import matplotlib.pyplot as plt

# %% [markdown]
# На самом деле мы уже импортировали matplotlib внутри %pylab inline в начале задания.
#
# Работать мы будем с той же выборкой покупкок. Добавим новую колонку с датой покупки.

# %%
import datetime

start = datetime.datetime(2018, 1, 1)
end = datetime.datetime(2018, 1, 31)
delta_seconds = int((end - start).total_seconds())

dates = pd.DataFrame(index=data.order_id.unique())
dates['date'] = [
    (start + datetime.timedelta(seconds=random.randint(0, delta_seconds))).strftime('%Y-%m-%d')
    for _ in range(data.order_id.nunique())]

# если DataFrame с покупками из прошлого заказа называется не df, замените на ваше название ниже
data['date'] = data.order_id.map(dates['date'])

# %% [markdown]
# #### 1. Постройте гистограмму распределения сумм покупок и гистограмму средних цен отдельных видов продуктов product_id.
#
# Изображайте на двух соседних графиках. Для используйте subplot.

# %%
Graph_1=data.groupby('order_id').agg({'price': 'sum'}).reset_index()
plt.subplot(1, 2, 1) #на 1(m) - 2(n) сетка создает оси в заданном p(1)
plt.plot(Graph_1.order_id,Graph_1.price)
Graph_2=data.groupby('product_id').agg({'price': 'mean'}).reset_index()
plt.subplot(1, 2, 2)
plt.plot(Graph_2.product_id,Graph_2.price)
plt.show() # ..1-ряд, 2-колонки, 2-график

# %% [markdown]
# #### 2. Постройте график зависимости суммы покупок от дней.

# %%
Graphic=data.groupby('date').agg({'price': 'sum'}).reset_index()
plt.plot(Graphic.date,Graphic.price)
plt.ylabel('Сумма покупок') ##располагаем
plt.xlabel('Дата')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# #### 3. Постройте средних сумм покупок по дням недели (bar plot).

# %%
data['Date'] = pd.to_datetime(data['date']) ##создаем новые колонки для определения зависимости в графике
sub = []
[sub.append(row['Date'].weekday()) for i, row in data.iterrows()]
data['Day'] = sub
data.head(5)
# Out:
#                 event_time             order_id           product_id  \
# 0  2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 1  2020-04-24 11:50:39 UTC  2294359932054536986  1515966223509089906
# 2  2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 3  2020-04-24 14:37:43 UTC  2294444024058086220  2273948319057183658
# 5  2020-04-26 08:45:57 UTC  2295716521449619559  1515966223509261697
#
#     category_id                category_code    brand   price       user_id  \
# 0  2.268105e+18           electronics.tablet  samsung  170.02  1.515916e+18
# 1  2.268105e+18           electronics.tablet  samsung  170.02  1.515916e+18
# 2  2.268105e+18  electronics.audio.headphone   huawei   77.52  1.515916e+18
# 3  2.268105e+18  electronics.audio.headphone   huawei   77.52  1.515916e+18
# 5  2.268105e+18      furniture.kitchen.table  maestro   39.33  1.515916e+18
#
#     check        date       Date  Day
# 0  340.04  2018-01-20 2018-01-20    5
# 1  340.04  2018-01-20 2018-01-20    5
# 2  155.04  2018-01-14 2018-01-14    6
# 3  155.04  2018-01-14 2018-01-14    6
# 5   39.33  2018-01-29 2018-01-29    0

# %%
Graphic2=data.groupby('Day').agg({'price': 'mean'}).reset_index()
plt.plot(Graphic2.Day,Graphic2.price)
plt.xlabel('Номер дня недели')
plt.ylabel('Средняя сумма покупок')
plt.show()

# %% [markdown]
# #### 4. Постройте график зависимости денег за товар от купленного количества (scatter plot).

# %%
xData = data.groupby('category_id')['product_id'].sum().values
yData = data.groupby('category_id')['price'].sum().values
plt.scatter(xData,yData)
plt.xlabel('Количество товаров в заказе')
plt.ylabel('Цена товара')
plt.show()
plt.savefig("Graph4.png")

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %%
plt.savefig("Graph4.png")

# %% [markdown]
# Кстати, существует надстройка над matplotlib под названием [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html). Иногда удобнее и красивее делать визуализации через неё.
